# %% [markdown]
# ## Using MoSH to fit body models to labeled mocaps
#
# We base this off of the two SOMA tutorials: [Run SOMA on SOMA dataset](https://github.com/nghorbani/soma/blob/main/src/tutorials/run_soma_on_soma_dataset.ipynb) and [Solve Already Labeled MoCaps with Mosh++](https://github.com/nghorbani/soma/blob/main/src/tutorials/solve_labeled_mocap.ipynb).
#
# Reading the [definitions](https://github.com/nghorbani/soma/tree/main/src/tutorials#definitions) of terminology is recommended.
#
# MoSH++ takes in labeled motion capture data and fits an SMPL body model to it. As a note, the original MoSH paper converted the motion capture data to a different body model; we use MoSH/MoSH++ interchangeably, with both referring to the MoSH++.
#
# A *labeled* motion capture is simply one that has markers assigned to the point cloud points for each frame. The exact names of the markers is not relevant, just their stability (Is the marker mapped to the same point consistently for each frame)  (TODO: verify this).
#
# From the [MoSH paper](https://files.is.tue.mpg.de/black/papers/MoSh.pdf):
#
# > Marker placement on the human body varies across subjects and sessions, consequently we do not assume that the exact marker placement is known. Instead, a key contribution of MoSh is that it solves for the observed marker locations relative to the 3D body model.
#
# The MoSH algorithm works in two steps:
#
# 1. Solving for Beta Parameters. A single frame from the sequence is picked, and the SMPL body model is fit to the frame. SMPL models, in their simplest form, have 82 parameters per frame: 23 joints, 3 parameters to represent each joint in 3d space with axis-angle rotation, 3 more parameters to represent the root of the body (global translation), and 10 Beta parameters to characterize the variation of body height, body proportion, and weight. Once these Beta Parameters are solved for, they are fixed, and are used to fit the rest of the frames in the sequence. This process can take 20-30minutes per subject.
# 2. With Betas fixed, MoSH++ fits the SMPL body model frame by frame for the sequence. This process takes ~2 seconds per frame.
#
# TODO: cite the paper that has the approximate times for each step.
#
# TODO: bring in info about how MoSH uses temporal smoothing for its frame-by-frame fitting.

# %% [markdown]
# ### Verify Environment

# %%
# %load_ext autoreload
# %autoreload 2

# If this doesn't work, something is wrong with the conda environment. Check conda-env.md
# Make sure you are using the right kernel
import soma
import psbody
import moshpp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from glob import glob
import os
import os.path as osp
import time

from loguru import logger

from soma.amass.mosh_manual import mosh_manual
from soma.tools.run_soma_multiple import run_soma_on_multiple_settings

# %% [markdown]
# ## Running MoSH
#
# First, we define the directories we will be using to find our mocaps, and where to store them as well.
# There are two ways to run MoSH: one, on already labeled mocap data, and two, from data that was labeled from SOMA. We will cover both.
# In this first way, we assume we have a folder of already labeled mocaps, and we simply pass folder(s) into `target_ds_names`. Ensure that each such folder has a `settings.json` with the gender information of the mocap data.

# %%
soma_work_base_dir = osp.join(os.getcwd(), 'soma-root')
support_base_dir = osp.join(soma_work_base_dir, 'support_files')

mocap_base_dir = osp.join(support_base_dir, 'evaluation_mocaps/original')

work_base_dir = osp.join(soma_work_base_dir, 'running_just_mosh')
temp_base_dir = osp.join(support_base_dir, 'render_out_temp')

soma_expr_id = 'V48_02_SuperSet' # the model we are using

soma_data_ids = ['OC_05_G_03_real_000_synt_100']

# list each of the dataset folders you want to process with MoSH
# Verify that the location of these folders is at TODO: fill this in
# For raw, unlabeled mocaps, make sure to run the labeling script first at `label.ipynb`
# Run on 'immersion_test' to see sample results on a few mocaps
target_ds_names = ['xrm01',]

# %% [markdown]
# ### View list of Mocaps to MoSH

# %%
def select(fname):
    '''
    Running MoSH takes time, so a filter can be applied if only a subset of mocaps is needed.
    '''
    if "S02" in fname:
        return True
    return False

# %%
# List out all filenames we want to MoSH.
from pprint import pprint
ds_name = target_ds_names[0] # only one dataset at a time
mocap_fnames = glob(osp.join(mocap_base_dir, ds_name,  '*/*.c3d'))

mocap_fnames= list(filter(select, mocap_fnames)) # by default, `select()` does not filter anything
pprint(f'#mocaps found for {ds_name}: {len(mocap_fnames)+1}')
pprint(f'mocaps:\t{[osp.basename(fname) for fname in mocap_fnames]}...')

# %% [markdown]
# ## Checking labelset

# %%
import ezc3d

# Open the C3D file
c3d_file = mocap_fnames[10]
c3d = ezc3d.c3d(c3d_file)

# Get the number of points in the file
point_labels = c3d['parameters']['POINT']['LABELS']['value']

# Print the list of label names
for label in point_labels:
    print(label)

# %%
# Configuring Logfiles
from datetime import datetime
now = datetime.now()
time_string = now.strftime("%Y-%m-%d_%H-%M-%S")
logfile_loc = f"logs/mosh_and_render_{time_string}.log"
logger.add(logfile_loc)
print(f"Logging to {logfile_loc}. No further messages will be printed to console.")
# try:
#     logger.remove(0) # remove the default logger
# except ValueError as e:
#     print(f"Default logger (stdout) not found: {e}. It has probably already been removed")
# Out:
# Logging to logs/mosh_and_render_2023-05-03_00-01-51.log. No further messages will be printed to console.

# %% [markdown]
# Pay special attention to the `mosh_stagei_perseq` variable. If true, EACH mocap will have its body solved independently (30-40 mins per mocap). If false, the body will be solved once, and used for all the data.
# Set `true` if the data is from different subjects -- or different markerlayouts -- or different sessions. The only time we should do false is for mocap data recorded in the same session, where no markers have moved (or fallen off/re-added in different places).

# %% [markdown]
# ## Rendering outputs
#
# After our files have been MoSHed, we can render the output SMPL mesh as an mp4, a series of pngs, and/or a blender file.
# We repeat a similar process to above, changing the `run_task` to render, as well as defining different configuration variables. We also need to define a `temp_base_dir` to store the intermediate rendering files.

# %%
run_soma_on_multiple_settings(
        soma_expr_ids=[
            soma_expr_id,
        ],
        soma_mocap_target_ds_names= target_ds_names,
        soma_data_ids=soma_data_ids,
        mosh_cfg={
            'moshpp.verbosity': 1, # set to 2 to visualize the process in meshviewer
            'dirs.work_base_dir': osp.join(work_base_dir, 'mosh_results'),
            'dirs.support_base_dir': support_base_dir,
            # 'mosh_stagei_perseq': True,
        },
        parallel_cfg={
            # 'max_num_jobs': 1,
            'randomly_run_jobs': True,
        },
        run_tasks=[
            'mosh',
        ],
        mocap_base_dir = mocap_base_dir,
        soma_work_base_dir=soma_work_base_dir,
        mocap_ext='.c3d',
        filter_fn=select
    )
# Out:
# 2023-05-16 03:59:26.208 | DEBUG    | soma.tools.run_soma_multiple:run_soma_on_multiple_settings:137 - After filtering, Found 171 mocaps for xrm01
# 2023-05-16 03:59:26.209 | DEBUG    | soma.tools.run_soma_multiple:run_soma_on_multiple_settings:138 - updatetest
# 2023-05-16 03:59:26.210 | DEBUG    | soma.tools.run_soma_multiple:run_soma_on_multiple_settings:143 - inloop
# > /home/ritaank/Documents/dev/motion_synthesis/soma-root-2/soma/src/soma/tools/run_soma_multiple.py(164)run_soma_on_multiple_settings()
#     162                         assert osp.exists(cur_soma_cfg.soma.expr_dir), FileExistsError(cur_soma_cfg.soma.expr_dir)
#     163                         set_trace()
# --> 164                         soma_labeled_mocap_fname = cur_soma_cfg.dirs.mocap_out_fname
#     165                         if not os.path.exists(soma_labeled_mocap_fname):
#     166                             soma_jobs.append(soma_job)
#
# 5
# False
# '/home/ritaank/Documents/dev/SOMA-interface/soma-root/training_experiments/V48_02_SuperSet/OC_05_G_03_real_000_synt_100/evaluations/soma_labeled_mocap_tracklet/xrm01/02/xrm01A22S02T15B22569E23163R.pkl'
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# /tmp/ipykernel_448216/2417206804.py in <module>
#      21         soma_work_base_dir=soma_work_base_dir,
#      22         mocap_ext='.c3d',
# ---> 23         filter_fn=select
#      24     )
#
# ~/Documents/dev/motion_synthesis/soma-root-2/soma/src/soma/tools/run_soma_multiple.py in run_soma_on_multiple_settings(soma_expr_ids, soma_mocap_target_ds_names, soma_data_ids, tracklet_labeling_options, ds_name_gt, soma_cfg, mosh_cfg, render_cfg, eval_label_cfg, parallel_cfg, eval_v2v_cfg, fast_dev_run, run_tasks, mocap_ext, mosh_stagei_perseq, fname_filter, soma_work_base_dir, mocap_base_dir, gt_mosh_base_dir, **kwargs)
#     162                         assert osp.exists(cur_soma_cfg.soma.expr_dir), FileExistsError(cur_soma_cfg.soma.expr_dir)
#     163                         set_trace()
# --> 164                         soma_labeled_mocap_fname = cur_soma_cfg.dirs.mocap_out_fname
#     165                         if not os.path.exists(soma_labeled_mocap_fname):
#     166                             soma_jobs.append(soma_job)
#
# ~/Documents/dev/motion_synthesis/soma-root-2/soma/src/soma/tools/run_soma_multiple.py in run_soma_on_multiple_settings(soma_expr_ids, soma_mocap_target_ds_names, soma_data_ids, tracklet_labeling_options, ds_name_gt, soma_cfg, mosh_cfg, render_cfg, eval_label_cfg, parallel_cfg, eval_v2v_cfg, fast_dev_run, run_tasks, mocap_ext, mosh_stagei_perseq, fname_filter, soma_work_base_dir, mocap_base_dir, gt_mosh_base_dir, **kwargs)
#     162                         assert osp.exists(cur_soma_cfg.soma.expr_dir), FileExistsError(cur_soma_cfg.soma.expr_dir)
#     163                         set_trace()
# --> 164                         soma_labeled_mocap_fname = cur_soma_cfg.dirs.mocap_out_fname
#     165                         if not os.path.exists(soma_labeled_mocap_fname):
#     166                             soma_jobs.append(soma_job)
#
# ~/miniconda3/envs/soma3/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~/miniconda3/envs/soma3/lib/python3.7/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %%
for ds_name in target_ds_names:
    mocap_fnames = glob(osp.join(mocap_base_dir, ds_name,  '*/*.c3d'))

    mocap_fnames = list(filter(select, mocap_fnames))

    logger.info(f'#mocaps found for {ds_name}: {len(mocap_fnames)}')

    mosh_manual(
        mocap_fnames,
        mosh_cfg={
            'moshpp.verbosity': 1, # set to 2 to visualize the process in meshviewer
            'dirs.work_base_dir': osp.join(work_base_dir, 'mosh_results'),
            'dirs.support_base_dir': support_base_dir,
            # 'mosh_stagei_perseq': True,
        },
        render_cfg={
            # 'render.render_only_one_image': True, # uncomment for initial testing of the pipeline
            'render.video_fps': 30,  # video_fps * ds_rate should equal the sample fps always
            'mesh.ds_rate': 8, # see above
            'render.resolution.change_from_blend': True,
            'render.resolution.default': [1600, 1600],  # [x,y]
            'render.render_engine': 'eevee',  # eevee / cycles,
        
            'dirs.work_base_dir': osp.join(work_base_dir, 'mp4_renders'),
            # 'render.show_markers': True,
            'render.save_final_blend_file': True,
            'dirs.support_base_dir': support_base_dir,
            'dirs.temp_base_dir': temp_base_dir
        },
        parallel_cfg={
            'pool_size': 5,
            # 'max_num_jobs': 2,
            'randomly_run_jobs': False,
        },
        run_tasks=[
            'mosh',
        ],
        fast_dev_run=False,
    )
# Out:
# soma_subject2 -- clap_002 -- 2481124905:<module>:6 -- #mocaps found for xrm01: 187
# soma_subject2 -- clap_002 -- mosh_manual:mosh_manual:113 -- Submitting MoSh++ jobs.
# soma_subject2 -- clap_002 -- parallel_tools:run_parallel_jobs:54 -- #Job(s) submitted: 1
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:__init__:95 -- mocap_fname: /home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T16B12669E13264R.c3d
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:__init__:97 -- stagei_fname: /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/01/female_stagei.pkl
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:__init__:98 -- stageii_fname: /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/01/xrm01A22S01T16B12669E13264R_stageii.pkl
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:__init__:103 -- surface_model: type: smplx; gender: female; fname:/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/smplx/female/model.pkl
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:__init__:107 -- optimize_fingers: False, optimize_face: False, optimize_toes: False, optimize_betas: True, optimize_dynamics: False
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:prepare_stagei_frames:154 -- 12 subject specific mocap(s) are selected for mosh stagei.
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:prepare_stagei_frames:157 -- Selecting 12 frames using method random_strict on frames with 100% least_avail_markers
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:prepare_stagei_frames:197 -- Using frames for stage-i: ['/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T05B19375E19882R.c3d_000043'
#  '/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T05B19375E19882R.c3d_000103'
#  '/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T05B19375E19882R.c3d_000110'
#  '/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T05B19375E19882R.c3d_000071'
#  '/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T05B19375E19882R.c3d_000127'
#  '/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T05B19375E19882R.c3d_000074'
#  '/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T05B19375E19882R.c3d_000112'
#  '/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T05B19375E19882R.c3d_000042'
#  '/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T05B19375E19882R.c3d_000041'
#  '/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T05B19375E19882R.c3d_000118'
#  '/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T05B19375E19882R.c3d_000049'
#  '/home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/evaluation_mocaps/original/xrm01/01/xrm01A22S01T16B19063E19658R.c3d_000531']
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:mosh_stagei:230 -- Marker layout not available. It will be produced: /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/xrm01_smplx.json
# 01 -- xrm01A22S01T16B12669E13264R -- create_marker_layout_for_mocaps:marker_labels_to_marker_layout:68 -- Preparing marker layout for surface_model_type: smplx
# 01 -- xrm01A22S01T16B12669E13264R -- create_marker_layout_for_mocaps:marker_labels_to_marker_layout:94 -- Unknown marker label(s) for surface_model_type smplx skipped: ['Hilt', 'Mid1', 'Mid2', 'Tip'].
# 01 -- xrm01A22S01T16B12669E13264R -- create_marker_layout_for_mocaps:marker_labels_to_marker_layout:106 -- has_face: True, has_finger: True, has_body: True, wrist_markers_on_stick: False
# 01 -- xrm01A22S01T16B12669E13264R -- create_marker_layout_for_mocaps:marker_labels_to_marker_layout:130 -- Created marker layout: /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/xrm01_smplx.json
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:mosh_stagei:240 -- Attempting mosh stagei to create /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/01/female_stagei.pkl
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:120 -- using marker_layout_fname: /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/xrm01_smplx.json
# 01 -- xrm01A22S01T16B12669E13264R -- edit_tools:marker_layout_load:130 -- Loading marker layout: /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/xrm01_smplx.json
# 01 -- xrm01A22S01T16B12669E13264R -- edit_tools:marker_layout_load:134 -- Available marker types: {'body': 39}. Total: 39 markers.
# 01 -- xrm01A22S01T16B12669E13264R -- bodymodel_loader:load_moshpp_models:93 -- Loading model: /home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/smplx/female/model.pkl
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:160 -- can_model.betas.shape: (400,)
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:161 -- opt_models[0].betas.shape: (400,)
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:180 -- Estimating for #latent markers: 39
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:217 -- Number of available markers in each stagei selected frames: (F00, 39), (F01, 39), (F02, 39), (F03, 39), (F04, 39), (F05, 39), (F06, 39), (F07, 39), (F08, 39), (F09, 39), (F10, 39), (F11, 39)
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:225 -- Rigidly aligning the body to the markers
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:250 -- MoSh stagei weights before annealing:
# stagei_wt_poseH: 3.0
# stagei_wt_poseF: 3.0
# stagei_wt_expr: 34.0
# stagei_wt_pose: 3.0
# stagei_wt_poseB: 3.0
# stagei_wt_init_finger_left: 400.0
# stagei_wt_init_finger_right: 400.0
# stagei_wt_init_finger: 400.0
# stagei_wt_betas: 10.0
# stagei_wt_init: 300
# stagei_wt_data: 75.0
# stagei_wt_surf: 10000.0
# stagei_wt_annealing: [1.0, 0.5, 0.25, 0.125]
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:254 -- head_marker_corr_fname is provided and is being loaded: /home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/ssm_head_marker_corr.npz
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:262 -- Successfully took into account the correlation of the head markers
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:268 -- Beginning mosh stagei with opt_settings.weights_type: smplx
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:342 -- Step 1/4 : Opt. wt_anneal_factor = 1.00, wt_data = 1.00, wt_poseB = 88.46
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:344 -- stagei_wt_init for different marker types body = 300.00:
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:409 -- Init. loss values: beta = 0.00e+00 | data = 1.07e+06 | init_body = 8.52e-27 | init_head_corr = 6.41e-29 | poseB = 2.46e+04 | surf = 6.53e+01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:417 -- Final loss values: beta = 3.66e+02 | data = 5.46e+03 | init_body = 4.66e+03 | init_head_corr = 1.29e+02 | poseB = 1.22e+04 | surf = 4.68e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:342 -- Step 2/4 : Opt. wt_anneal_factor = 0.50, wt_data = 0.50, wt_poseB = 176.92
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:344 -- stagei_wt_init for different marker types body = 150.00:
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:409 -- Init. loss values: beta = 9.16e+01 | data = 2.18e+04 | init_body = 1.16e+03 | init_head_corr = 3.22e+01 | poseB = 3.04e+03 | surf = 4.68e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:417 -- Final loss values: beta = 2.39e+02 | data = 1.28e+03 | init_body = 3.80e+03 | init_head_corr = 2.15e+02 | poseB = 3.25e+03 | surf = 1.45e+00
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:342 -- Step 3/4 : Opt. wt_anneal_factor = 0.25, wt_data = 0.25, wt_poseB = 353.85
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:344 -- stagei_wt_init for different marker types body = 75.00:
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:409 -- Init. loss values: beta = 5.97e+01 | data = 5.11e+03 | init_body = 9.49e+02 | init_head_corr = 5.36e+01 | poseB = 8.12e+02 | surf = 1.45e+00
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:417 -- Final loss values: beta = 1.09e+02 | data = 2.24e+03 | init_body = 1.05e+03 | init_head_corr = 9.34e+01 | poseB = 8.97e+02 | surf = 9.38e+00
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:342 -- Step 4/4 : Opt. wt_anneal_factor = 0.12, wt_data = 0.12, wt_poseB = 707.69
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:344 -- stagei_wt_init for different marker types body = 37.50:
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:409 -- Init. loss values: beta = 2.74e+01 | data = 8.96e+03 | init_body = 2.63e+02 | init_head_corr = 2.34e+01 | poseB = 2.24e+02 | surf = 9.38e+00
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stagei:417 -- Final loss values: beta = 3.41e+01 | data = 6.55e+03 | init_body = 2.67e+02 | init_head_corr = 2.74e+01 | poseB = 2.45e+02 | surf = 3.15e+01
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:mosh_stagei:257 -- created stagei_fname: /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/01/female_stagei.pkl
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:mosh_stagei:259 -- finished mosh stagei in 0:18:59.836552
# /home/ritaank/miniconda3/envs/soma3/lib/python3.7/site-packages/omegaconf/resolvers/oc/__init__.py:91: UserWarning: 'dirs.markerlyout_basename' is deprecated. Change your code and config to use 'dirs.marker_layout.basename'
#   warnings.warn(category=UserWarning, message=msg)
# /home/ritaank/miniconda3/envs/soma3/lib/python3.7/site-packages/omegaconf/resolvers/oc/__init__.py:91: UserWarning: 'dirs.marker_layout_fname' is deprecated. Change your code and config to use 'dirs.marker_layout.fname'
#   warnings.warn(category=UserWarning, message=msg)
# 01 -- xrm01A22S01T16B12669E13264R -- edit_tools:marker_layout_load:130 -- Loading marker layout: /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/01/female_stagei.json
# 01 -- xrm01A22S01T16B12669E13264R -- edit_tools:marker_layout_load:134 -- Available marker types: {'body': 39}. Total: 39 markers.
# 01 -- xrm01A22S01T16B12669E13264R -- edit_tools:marker_layout_load:130 -- Loading marker layout: /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/01/female_stagei.json
# 01 -- xrm01A22S01T16B12669E13264R -- edit_tools:marker_layout_load:134 -- Available marker types: {'body': 39}. Total: 39 markers.
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:dump_stagei_marker_layout:338 -- created /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/01/female_stagei.json
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:dump_stagei_marker_layout:339 -- created /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/01/female_stagei.ply
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:dump_stagei_marker_layout:340 -- created /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/01/female_stagei.c3d
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:run_moshpp_once:600 -- Final mosh stagei loss: data = 4.29e+07 | poseB = 5.98e+04 | init_body = 7.12e+04 | init_head_corr = 7.53e+02 | beta = 1.16e+03 | surf = 9.90e+02
# 01 -- xrm01A22S01T16B12669E13264R -- mosh_head:mosh_stageii:277 -- attempting mosh stageii to create /home/ritaank/Documents/dev/SOMA-interface/soma-root/running_just_mosh/mosh_results/xrm01/01/xrm01A22S01T16B12669E13264R_stageii.pkl
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:473 -- Loaded mocap markers for mosh stageii
# 01 -- xrm01A22S01T16B12669E13264R -- bodymodel_loader:load_moshpp_models:93 -- Loading model: /home/ritaank/Documents/dev/SOMA-interface/soma-root/support_files/smplx/female/model.pkl
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:505 -- #observed, #simulated markers: 43, 39
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:533 -- mosh stageii weights are subject to change during the optimization, depending on how many markers are absent in each frame.
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:537 -- MoSh stagei weights before annealing:
# stageii_wt_data: 400
# stageii_wt_velo: 2.5
# stageii_wt_dmpl: 1.0
# stageii_wt_expr: 1.0
# stageii_wt_poseB: 1.6
# stageii_wt_poseH: 1.0
# stageii_wt_poseF: 1.0
# stageii_wt_annealing: 2.5
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:541 -- Starting mosh stageii for 596 frames.
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:631 -- Rigidly aligning the markers to the body...
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0000/0596 -- Step 1. initial loss values: data = 2.43e+03 | poseB = 1.19e+03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0000/0596 -- Step 1. final loss values: data = 2.43e+03 | poseB = 1.19e+03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0000/0596 -- Step 2. initial loss values: data = 2.43e+03 | poseB = 1.19e+03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0000/0596 -- Step 2. final loss values: data = 2.43e+03 | poseB = 1.19e+03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0001/0596 -- Step 1. initial loss values: data = 2.43e+03 | poseB = 1.19e+03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0001/0596 -- Step 1. final loss values: data = 2.43e+03 | poseB = 1.19e+03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0001/0596 -- Step 2. initial loss values: data = 2.43e+03 | poseB = 1.19e+03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0001/0596 -- Step 2. final loss values: data = 2.43e+03 | poseB = 1.19e+03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0002/0596 -- Step 1. initial loss values: data = 2.43e+03 | poseB = 1.19e+03 | velo = 2.04e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0002/0596 -- Step 1. final loss values: data = 2.43e+03 | poseB = 1.19e+03 | velo = 1.24e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0002/0596 -- Step 2. initial loss values: data = 2.43e+03 | poseB = 1.19e+03 | velo = 1.24e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0002/0596 -- Step 2. final loss values: data = 2.43e+03 | poseB = 1.19e+03 | velo = 1.24e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0003/0596 -- Step 1. initial loss values: data = 2.43e+03 | poseB = 1.19e+03 | velo = 1.10e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0003/0596 -- Step 1. final loss values: data = 2.43e+03 | poseB = 1.19e+03 | velo = 8.71e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0003/0596 -- Step 2. initial loss values: data = 2.43e+03 | poseB = 1.19e+03 | velo = 8.71e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0003/0596 -- Step 2. final loss values: data = 2.43e+03 | poseB = 1.19e+03 | velo = 8.62e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0004/0596 -- Step 1. initial loss values: data = 2.44e+03 | poseB = 1.19e+03 | velo = 2.61e-05
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0004/0596 -- Step 1. final loss values: data = 2.44e+03 | poseB = 1.19e+03 | velo = 1.48e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0004/0596 -- Step 2. initial loss values: data = 2.44e+03 | poseB = 1.19e+03 | velo = 1.48e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0004/0596 -- Step 2. final loss values: data = 2.44e+03 | poseB = 1.19e+03 | velo = 1.49e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0005/0596 -- Step 1. initial loss values: data = 2.44e+03 | poseB = 1.19e+03 | velo = 2.01e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0005/0596 -- Step 1. final loss values: data = 2.44e+03 | poseB = 1.18e+03 | velo = 1.55e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0005/0596 -- Step 2. initial loss values: data = 2.44e+03 | poseB = 1.18e+03 | velo = 1.55e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0005/0596 -- Step 2. final loss values: data = 2.44e+03 | poseB = 1.18e+03 | velo = 1.55e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0006/0596 -- Step 1. initial loss values: data = 2.44e+03 | poseB = 1.18e+03 | velo = 2.33e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0006/0596 -- Step 1. final loss values: data = 2.44e+03 | poseB = 1.18e+03 | velo = 7.81e-05
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0006/0596 -- Step 2. initial loss values: data = 2.44e+03 | poseB = 1.18e+03 | velo = 7.81e-05
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0006/0596 -- Step 2. final loss values: data = 2.44e+03 | poseB = 1.18e+03 | velo = 7.81e-05
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0007/0596 -- Step 1. initial loss values: data = 2.43e+03 | poseB = 1.18e+03 | velo = 2.86e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0007/0596 -- Step 1. final loss values: data = 2.43e+03 | poseB = 1.18e+03 | velo = 1.38e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0007/0596 -- Step 2. initial loss values: data = 2.43e+03 | poseB = 1.18e+03 | velo = 1.38e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0007/0596 -- Step 2. final loss values: data = 2.43e+03 | poseB = 1.18e+03 | velo = 1.38e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0008/0596 -- Step 1. initial loss values: data = 2.43e+03 | poseB = 1.18e+03 | velo = 1.27e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0008/0596 -- Step 1. final loss values: data = 2.43e+03 | poseB = 1.18e+03 | velo = 1.58e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0008/0596 -- Step 2. initial loss values: data = 2.43e+03 | poseB = 1.18e+03 | velo = 1.58e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0008/0596 -- Step 2. final loss values: data = 2.43e+03 | poseB = 1.18e+03 | velo = 1.58e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0009/0596 -- Step 1. initial loss values: data = 2.47e+03 | poseB = 1.30e+03 | velo = 1.69e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0009/0596 -- Step 1. final loss values: data = 2.37e+03 | poseB = 1.29e+03 | velo = 1.12e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0009/0596 -- Step 2. initial loss values: data = 2.37e+03 | poseB = 1.29e+03 | velo = 1.12e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0009/0596 -- Step 2. final loss values: data = 2.37e+03 | poseB = 1.29e+03 | velo = 1.12e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0010/0596 -- Step 1. initial loss values: data = 2.37e+03 | poseB = 1.29e+03 | velo = 1.09e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0010/0596 -- Step 1. final loss values: data = 2.37e+03 | poseB = 1.29e+03 | velo = 1.05e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0010/0596 -- Step 2. initial loss values: data = 2.37e+03 | poseB = 1.29e+03 | velo = 1.05e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0010/0596 -- Step 2. final loss values: data = 2.37e+03 | poseB = 1.29e+03 | velo = 1.05e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0011/0596 -- Step 1. initial loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 3.87e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0011/0596 -- Step 1. final loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 9.35e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0011/0596 -- Step 2. initial loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 9.35e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0011/0596 -- Step 2. final loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 9.35e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0012/0596 -- Step 1. initial loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 1.62e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0012/0596 -- Step 1. final loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 2.49e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0012/0596 -- Step 2. initial loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 2.49e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0012/0596 -- Step 2. final loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 2.49e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0013/0596 -- Step 1. initial loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 5.95e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0013/0596 -- Step 1. final loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 5.38e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0013/0596 -- Step 2. initial loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 5.38e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0013/0596 -- Step 2. final loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 5.31e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0014/0596 -- Step 1. initial loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 3.63e-05
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0014/0596 -- Step 1. final loss values: data = 2.38e+03 | poseB = 1.28e+03 | velo = 1.13e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0014/0596 -- Step 2. initial loss values: data = 2.38e+03 | poseB = 1.28e+03 | velo = 1.13e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0014/0596 -- Step 2. final loss values: data = 2.38e+03 | poseB = 1.28e+03 | velo = 1.13e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0015/0596 -- Step 1. initial loss values: data = 2.38e+03 | poseB = 1.28e+03 | velo = 1.37e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0015/0596 -- Step 1. final loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 3.13e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0015/0596 -- Step 2. initial loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 3.13e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0015/0596 -- Step 2. final loss values: data = 2.38e+03 | poseB = 1.29e+03 | velo = 3.56e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0016/0596 -- Step 1. initial loss values: data = 2.64e+03 | poseB = 1.17e+03 | velo = 1.70e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0016/0596 -- Step 1. final loss values: data = 2.42e+03 | poseB = 1.18e+03 | velo = 1.11e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0016/0596 -- Step 2. initial loss values: data = 2.42e+03 | poseB = 1.18e+03 | velo = 1.11e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0016/0596 -- Step 2. final loss values: data = 2.42e+03 | poseB = 1.18e+03 | velo = 1.20e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0017/0596 -- Step 1. initial loss values: data = 2.42e+03 | poseB = 1.18e+03 | velo = 1.18e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0017/0596 -- Step 1. final loss values: data = 2.41e+03 | poseB = 1.18e+03 | velo = 1.12e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0017/0596 -- Step 2. initial loss values: data = 2.41e+03 | poseB = 1.18e+03 | velo = 1.12e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0017/0596 -- Step 2. final loss values: data = 2.41e+03 | poseB = 1.18e+03 | velo = 1.10e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0018/0596 -- Step 1. initial loss values: data = 2.34e+03 | poseB = 1.18e+03 | velo = 1.90e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0018/0596 -- Step 1. final loss values: data = 2.23e+03 | poseB = 1.18e+03 | velo = 7.31e-02
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0018/0596 -- Step 2. initial loss values: data = 2.23e+03 | poseB = 1.18e+03 | velo = 7.31e-02
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0018/0596 -- Step 2. final loss values: data = 2.23e+03 | poseB = 1.18e+03 | velo = 7.84e-02
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0019/0596 -- Step 1. initial loss values: data = 2.23e+03 | poseB = 1.18e+03 | velo = 6.73e-02
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0019/0596 -- Step 1. final loss values: data = 2.23e+03 | poseB = 1.18e+03 | velo = 5.36e-02
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0019/0596 -- Step 2. initial loss values: data = 2.23e+03 | poseB = 1.18e+03 | velo = 5.36e-02
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0019/0596 -- Step 2. final loss values: data = 2.23e+03 | poseB = 1.18e+03 | velo = 5.36e-02
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0020/0596 -- Step 1. initial loss values: data = 2.24e+03 | poseB = 1.18e+03 | velo = 1.64e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0020/0596 -- Step 1. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 2.17e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0020/0596 -- Step 2. initial loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 2.17e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0020/0596 -- Step 2. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 2.17e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0021/0596 -- Step 1. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 7.96e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0021/0596 -- Step 1. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.86e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0021/0596 -- Step 2. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.86e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0021/0596 -- Step 2. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 2.01e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0022/0596 -- Step 1. initial loss values: data = 2.26e+03 | poseB = 1.19e+03 | velo = 1.24e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0022/0596 -- Step 1. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 2.09e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0022/0596 -- Step 2. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 2.09e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0022/0596 -- Step 2. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 2.10e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0023/0596 -- Step 1. initial loss values: data = 2.26e+03 | poseB = 1.19e+03 | velo = 6.60e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0023/0596 -- Step 1. final loss values: data = 2.26e+03 | poseB = 1.19e+03 | velo = 1.75e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0023/0596 -- Step 2. initial loss values: data = 2.26e+03 | poseB = 1.19e+03 | velo = 1.75e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0023/0596 -- Step 2. final loss values: data = 2.26e+03 | poseB = 1.19e+03 | velo = 1.75e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0024/0596 -- Step 1. initial loss values: data = 2.26e+03 | poseB = 1.19e+03 | velo = 8.03e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0024/0596 -- Step 1. final loss values: data = 2.26e+03 | poseB = 1.19e+03 | velo = 1.68e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0024/0596 -- Step 2. initial loss values: data = 2.26e+03 | poseB = 1.19e+03 | velo = 1.68e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0024/0596 -- Step 2. final loss values: data = 2.26e+03 | poseB = 1.19e+03 | velo = 1.68e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0025/0596 -- Step 1. initial loss values: data = 2.27e+03 | poseB = 1.19e+03 | velo = 3.33e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0025/0596 -- Step 1. final loss values: data = 2.27e+03 | poseB = 1.19e+03 | velo = 1.49e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0025/0596 -- Step 2. initial loss values: data = 2.27e+03 | poseB = 1.19e+03 | velo = 1.49e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0025/0596 -- Step 2. final loss values: data = 2.27e+03 | poseB = 1.19e+03 | velo = 1.49e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0026/0596 -- Step 1. initial loss values: data = 2.27e+03 | poseB = 1.19e+03 | velo = 8.61e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0026/0596 -- Step 1. final loss values: data = 2.27e+03 | poseB = 1.19e+03 | velo = 1.70e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0026/0596 -- Step 2. initial loss values: data = 2.27e+03 | poseB = 1.19e+03 | velo = 1.70e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0026/0596 -- Step 2. final loss values: data = 2.27e+03 | poseB = 1.19e+03 | velo = 1.70e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0027/0596 -- Step 1. initial loss values: data = 2.28e+03 | poseB = 1.19e+03 | velo = 6.63e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0027/0596 -- Step 1. final loss values: data = 2.28e+03 | poseB = 1.18e+03 | velo = 2.73e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0027/0596 -- Step 2. initial loss values: data = 2.28e+03 | poseB = 1.18e+03 | velo = 2.73e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0027/0596 -- Step 2. final loss values: data = 2.28e+03 | poseB = 1.18e+03 | velo = 3.15e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0028/0596 -- Step 1. initial loss values: data = 2.26e+03 | poseB = 1.18e+03 | velo = 1.47e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0028/0596 -- Step 1. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 7.67e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0028/0596 -- Step 2. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 7.67e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0028/0596 -- Step 2. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 8.15e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0029/0596 -- Step 1. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 3.10e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0029/0596 -- Step 1. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 2.04e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0029/0596 -- Step 2. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 2.04e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0029/0596 -- Step 2. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 2.04e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0030/0596 -- Step 1. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 2.45e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0030/0596 -- Step 1. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 8.75e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0030/0596 -- Step 2. initial loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 8.75e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0030/0596 -- Step 2. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 9.57e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0031/0596 -- Step 1. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 6.96e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0031/0596 -- Step 1. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 2.55e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0031/0596 -- Step 2. initial loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 2.55e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0031/0596 -- Step 2. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 2.55e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0032/0596 -- Step 1. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 9.58e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0032/0596 -- Step 1. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 8.48e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0032/0596 -- Step 2. initial loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 8.48e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0032/0596 -- Step 2. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 8.48e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0033/0596 -- Step 1. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.37e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0033/0596 -- Step 1. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.01e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0033/0596 -- Step 2. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.01e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0033/0596 -- Step 2. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.29e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0034/0596 -- Step 1. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.22e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0034/0596 -- Step 1. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 4.36e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0034/0596 -- Step 2. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 4.36e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0034/0596 -- Step 2. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 4.91e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0035/0596 -- Step 1. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.52e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0035/0596 -- Step 1. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.68e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0035/0596 -- Step 2. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.68e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0035/0596 -- Step 2. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.72e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0036/0596 -- Step 1. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 9.65e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0036/0596 -- Step 1. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.58e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0036/0596 -- Step 2. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.58e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0036/0596 -- Step 2. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.97e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0037/0596 -- Step 1. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 1.44e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0037/0596 -- Step 1. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 4.33e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0037/0596 -- Step 2. initial loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 4.33e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0037/0596 -- Step 2. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 4.60e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0038/0596 -- Step 1. initial loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 1.60e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0038/0596 -- Step 1. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 1.38e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0038/0596 -- Step 2. initial loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 1.38e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0038/0596 -- Step 2. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 1.40e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0039/0596 -- Step 1. initial loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 1.96e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0039/0596 -- Step 1. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 2.10e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0039/0596 -- Step 2. initial loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 2.10e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0039/0596 -- Step 2. final loss values: data = 2.24e+03 | poseB = 1.19e+03 | velo = 1.91e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0040/0596 -- Step 1. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 2.19e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0040/0596 -- Step 1. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 6.64e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0040/0596 -- Step 2. initial loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 6.64e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0040/0596 -- Step 2. final loss values: data = 2.25e+03 | poseB = 1.19e+03 | velo = 8.24e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0041/0596 -- Step 1. initial loss values: data = 2.28e+03 | poseB = 1.19e+03 | velo = 7.06e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0041/0596 -- Step 1. final loss values: data = 2.27e+03 | poseB = 1.19e+03 | velo = 3.06e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0041/0596 -- Step 2. initial loss values: data = 2.27e+03 | poseB = 1.19e+03 | velo = 3.06e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0041/0596 -- Step 2. final loss values: data = 2.27e+03 | poseB = 1.19e+03 | velo = 4.58e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0042/0596 -- Step 1. initial loss values: data = 2.32e+03 | poseB = 1.19e+03 | velo = 1.92e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0042/0596 -- Step 1. final loss values: data = 2.31e+03 | poseB = 1.19e+03 | velo = 9.73e-05
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0042/0596 -- Step 2. initial loss values: data = 2.31e+03 | poseB = 1.19e+03 | velo = 9.73e-05
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0042/0596 -- Step 2. final loss values: data = 2.31e+03 | poseB = 1.19e+03 | velo = 1.27e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0043/0596 -- Step 1. initial loss values: data = 2.39e+03 | poseB = 1.19e+03 | velo = 2.62e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0043/0596 -- Step 1. final loss values: data = 2.38e+03 | poseB = 1.19e+03 | velo = 1.02e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0043/0596 -- Step 2. initial loss values: data = 2.38e+03 | poseB = 1.19e+03 | velo = 1.02e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0043/0596 -- Step 2. final loss values: data = 2.38e+03 | poseB = 1.19e+03 | velo = 1.79e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0044/0596 -- Step 1. initial loss values: data = 2.48e+03 | poseB = 1.31e+03 | velo = 6.15e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0044/0596 -- Step 1. final loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 1.04e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0044/0596 -- Step 2. initial loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 1.04e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0044/0596 -- Step 2. final loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 1.04e-01
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0045/0596 -- Step 1. initial loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 6.64e-02
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0045/0596 -- Step 1. final loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 5.72e-02
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0045/0596 -- Step 2. initial loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 5.72e-02
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0045/0596 -- Step 2. final loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 5.72e-02
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0046/0596 -- Step 1. initial loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 1.20e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0046/0596 -- Step 1. final loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 7.33e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0046/0596 -- Step 2. initial loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 7.33e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0046/0596 -- Step 2. final loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 7.33e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0047/0596 -- Step 1. initial loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 4.48e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0047/0596 -- Step 1. final loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 9.04e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0047/0596 -- Step 2. initial loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 9.04e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0047/0596 -- Step 2. final loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 9.04e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0048/0596 -- Step 1. initial loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 8.22e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0048/0596 -- Step 1. final loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 2.50e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0048/0596 -- Step 2. initial loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 2.50e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0048/0596 -- Step 2. final loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 2.50e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0049/0596 -- Step 1. initial loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 4.89e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0049/0596 -- Step 1. final loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 1.42e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0049/0596 -- Step 2. initial loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 1.42e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0049/0596 -- Step 2. final loss values: data = 2.42e+03 | poseB = 1.30e+03 | velo = 2.93e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0050/0596 -- Step 1. initial loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 9.86e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0050/0596 -- Step 1. final loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 1.04e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0050/0596 -- Step 2. initial loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 1.04e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0050/0596 -- Step 2. final loss values: data = 2.43e+03 | poseB = 1.30e+03 | velo = 1.07e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0051/0596 -- Step 1. initial loss values: data = 2.31e+03 | poseB = 1.18e+03 | velo = 1.35e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0051/0596 -- Step 1. final loss values: data = 2.28e+03 | poseB = 1.19e+03 | velo = 6.19e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0051/0596 -- Step 2. initial loss values: data = 2.28e+03 | poseB = 1.19e+03 | velo = 6.19e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0051/0596 -- Step 2. final loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 8.21e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0052/0596 -- Step 1. initial loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 8.87e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0052/0596 -- Step 1. final loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 7.91e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0052/0596 -- Step 2. initial loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 7.91e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0052/0596 -- Step 2. final loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 7.53e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0053/0596 -- Step 1. initial loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 2.26e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0053/0596 -- Step 1. final loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 3.14e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0053/0596 -- Step 2. initial loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 3.14e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0053/0596 -- Step 2. final loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 3.34e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0054/0596 -- Step 1. initial loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 2.60e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0054/0596 -- Step 1. final loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 6.24e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0054/0596 -- Step 2. initial loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 6.24e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0054/0596 -- Step 2. final loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 7.66e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0055/0596 -- Step 1. initial loss values: data = 2.27e+03 | poseB = 1.20e+03 | velo = 4.63e-04
# ...
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0114/0596 -- Step 2. initial loss values: data = 2.25e+03 | poseB = 1.21e+03 | velo = 4.03e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0114/0596 -- Step 2. final loss values: data = 2.25e+03 | poseB = 1.21e+03 | velo = 4.03e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0115/0596 -- Step 1. initial loss values: data = 2.24e+03 | poseB = 1.21e+03 | velo = 7.36e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0115/0596 -- Step 1. final loss values: data = 2.23e+03 | poseB = 1.21e+03 | velo = 1.05e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0115/0596 -- Step 2. initial loss values: data = 2.23e+03 | poseB = 1.21e+03 | velo = 1.05e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0115/0596 -- Step 2. final loss values: data = 2.23e+03 | poseB = 1.21e+03 | velo = 1.06e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0116/0596 -- Step 1. initial loss values: data = 2.23e+03 | poseB = 1.21e+03 | velo = 1.59e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0116/0596 -- Step 1. final loss values: data = 2.23e+03 | poseB = 1.21e+03 | velo = 5.49e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0116/0596 -- Step 2. initial loss values: data = 2.23e+03 | poseB = 1.21e+03 | velo = 5.49e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0116/0596 -- Step 2. final loss values: data = 2.23e+03 | poseB = 1.21e+03 | velo = 5.43e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0117/0596 -- Step 1. initial loss values: data = 2.24e+03 | poseB = 1.21e+03 | velo = 7.59e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0117/0596 -- Step 1. final loss values: data = 2.24e+03 | poseB = 1.21e+03 | velo = 3.30e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0117/0596 -- Step 2. initial loss values: data = 2.24e+03 | poseB = 1.21e+03 | velo = 3.30e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0117/0596 -- Step 2. final loss values: data = 2.24e+03 | poseB = 1.21e+03 | velo = 3.79e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0118/0596 -- Step 1. initial loss values: data = 2.24e+03 | poseB = 1.21e+03 | velo = 1.05e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0118/0596 -- Step 1. final loss values: data = 2.23e+03 | poseB = 1.21e+03 | velo = 3.52e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0118/0596 -- Step 2. initial loss values: data = 2.23e+03 | poseB = 1.21e+03 | velo = 3.52e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0118/0596 -- Step 2. final loss values: data = 2.23e+03 | poseB = 1.21e+03 | velo = 4.41e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0119/0596 -- Step 1. initial loss values: data = 2.24e+03 | poseB = 1.21e+03 | velo = 1.24e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0119/0596 -- Step 1. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 1.47e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0119/0596 -- Step 2. initial loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 1.47e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0119/0596 -- Step 2. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 1.98e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0120/0596 -- Step 1. initial loss values: data = 2.24e+03 | poseB = 1.22e+03 | velo = 3.05e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0120/0596 -- Step 1. final loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 1.80e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0120/0596 -- Step 2. initial loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 1.80e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0120/0596 -- Step 2. final loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 1.80e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0121/0596 -- Step 1. initial loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 1.89e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0121/0596 -- Step 1. final loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 5.14e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0121/0596 -- Step 2. initial loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 5.14e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0121/0596 -- Step 2. final loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 5.48e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0122/0596 -- Step 1. initial loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 1.47e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0122/0596 -- Step 1. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 7.52e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0122/0596 -- Step 2. initial loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 7.52e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0122/0596 -- Step 2. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 9.73e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0123/0596 -- Step 1. initial loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 1.31e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0123/0596 -- Step 1. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 6.30e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0123/0596 -- Step 2. initial loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 6.30e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0123/0596 -- Step 2. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 6.29e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0124/0596 -- Step 1. initial loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 1.09e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0124/0596 -- Step 1. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 6.23e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0124/0596 -- Step 2. initial loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 6.23e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0124/0596 -- Step 2. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 7.56e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0125/0596 -- Step 1. initial loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 1.89e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0125/0596 -- Step 1. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 6.21e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0125/0596 -- Step 2. initial loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 6.21e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0125/0596 -- Step 2. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 6.74e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0126/0596 -- Step 1. initial loss values: data = 2.23e+03 | poseB = 1.22e+03 | velo = 1.78e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0126/0596 -- Step 1. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 6.41e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0126/0596 -- Step 2. initial loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 6.41e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0126/0596 -- Step 2. final loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 7.02e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0127/0596 -- Step 1. initial loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 2.27e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0127/0596 -- Step 1. final loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 7.74e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0127/0596 -- Step 2. initial loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 7.74e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0127/0596 -- Step 2. final loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 8.92e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0128/0596 -- Step 1. initial loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 2.13e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0128/0596 -- Step 1. final loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 9.33e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0128/0596 -- Step 2. initial loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 9.33e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0128/0596 -- Step 2. final loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 8.02e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0129/0596 -- Step 1. initial loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 1.87e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0129/0596 -- Step 1. final loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 5.35e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0129/0596 -- Step 2. initial loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 5.35e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0129/0596 -- Step 2. final loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 4.55e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0130/0596 -- Step 1. initial loss values: data = 2.22e+03 | poseB = 1.22e+03 | velo = 1.92e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0130/0596 -- Step 1. final loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 7.12e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0130/0596 -- Step 2. initial loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 7.12e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0130/0596 -- Step 2. final loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 7.92e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0131/0596 -- Step 1. initial loss values: data = 2.21e+03 | poseB = 1.22e+03 | velo = 2.36e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0131/0596 -- Step 1. final loss values: data = 2.19e+03 | poseB = 1.22e+03 | velo = 6.06e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0131/0596 -- Step 2. initial loss values: data = 2.19e+03 | poseB = 1.22e+03 | velo = 6.06e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0131/0596 -- Step 2. final loss values: data = 2.19e+03 | poseB = 1.22e+03 | velo = 8.28e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0132/0596 -- Step 1. initial loss values: data = 2.20e+03 | poseB = 1.22e+03 | velo = 2.29e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0132/0596 -- Step 1. final loss values: data = 2.19e+03 | poseB = 1.23e+03 | velo = 9.27e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0132/0596 -- Step 2. initial loss values: data = 2.19e+03 | poseB = 1.23e+03 | velo = 9.27e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0132/0596 -- Step 2. final loss values: data = 2.19e+03 | poseB = 1.23e+03 | velo = 9.02e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0133/0596 -- Step 1. initial loss values: data = 2.20e+03 | poseB = 1.23e+03 | velo = 2.01e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0133/0596 -- Step 1. final loss values: data = 2.19e+03 | poseB = 1.23e+03 | velo = 6.40e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0133/0596 -- Step 2. initial loss values: data = 2.19e+03 | poseB = 1.23e+03 | velo = 6.40e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0133/0596 -- Step 2. final loss values: data = 2.19e+03 | poseB = 1.23e+03 | velo = 6.40e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0134/0596 -- Step 1. initial loss values: data = 2.20e+03 | poseB = 1.23e+03 | velo = 2.70e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0134/0596 -- Step 1. final loss values: data = 2.19e+03 | poseB = 1.22e+03 | velo = 5.81e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0134/0596 -- Step 2. initial loss values: data = 2.19e+03 | poseB = 1.22e+03 | velo = 5.81e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0134/0596 -- Step 2. final loss values: data = 2.19e+03 | poseB = 1.22e+03 | velo = 5.81e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0135/0596 -- Step 1. initial loss values: data = 2.18e+03 | poseB = 1.22e+03 | velo = 2.21e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0135/0596 -- Step 1. final loss values: data = 2.17e+03 | poseB = 1.22e+03 | velo = 6.33e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0135/0596 -- Step 2. initial loss values: data = 2.17e+03 | poseB = 1.22e+03 | velo = 6.33e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0135/0596 -- Step 2. final loss values: data = 2.17e+03 | poseB = 1.22e+03 | velo = 6.33e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0136/0596 -- Step 1. initial loss values: data = 2.18e+03 | poseB = 1.22e+03 | velo = 2.83e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0136/0596 -- Step 1. final loss values: data = 2.16e+03 | poseB = 1.23e+03 | velo = 9.32e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0136/0596 -- Step 2. initial loss values: data = 2.16e+03 | poseB = 1.23e+03 | velo = 9.32e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0136/0596 -- Step 2. final loss values: data = 2.16e+03 | poseB = 1.23e+03 | velo = 1.13e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0137/0596 -- Step 1. initial loss values: data = 2.17e+03 | poseB = 1.23e+03 | velo = 3.61e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0137/0596 -- Step 1. final loss values: data = 2.16e+03 | poseB = 1.23e+03 | velo = 1.18e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0137/0596 -- Step 2. initial loss values: data = 2.16e+03 | poseB = 1.23e+03 | velo = 1.18e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0137/0596 -- Step 2. final loss values: data = 2.16e+03 | poseB = 1.23e+03 | velo = 9.29e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0138/0596 -- Step 1. initial loss values: data = 2.18e+03 | poseB = 1.23e+03 | velo = 2.45e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0138/0596 -- Step 1. final loss values: data = 2.17e+03 | poseB = 1.22e+03 | velo = 6.87e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0138/0596 -- Step 2. initial loss values: data = 2.17e+03 | poseB = 1.22e+03 | velo = 6.87e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:707 -- 0138/0596 -- Step 2. final loss values: data = 2.17e+03 | poseB = 1.22e+03 | velo = 6.87e-04
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:663 -- 0139/0596 -- Step 1. initial loss values: data = 2.17e+03 | poseB = 1.22e+03 | velo = 1.90e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:673 -- 0139/0596 -- Step 1. final loss values: data = 2.15e+03 | poseB = 1.22e+03 | velo = 2.28e-03
# 01 -- xrm01A22S01T16B12669E13264R -- chmosh:mosh_stageii:702 -- 0139/0596 -- Step 2. initial loss values: data = 2.15e+03 | poseB = 1.22e+03 | velo = 2.28e-03
